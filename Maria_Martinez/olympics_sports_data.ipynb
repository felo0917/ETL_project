# %%
import pandas as pd
from sqlalchemy import create_engine
from secret import username, password
import numpy as np

# %% [markdown]
# # Extract CSV into DataFrame

# %%
file = 'Resources/athlete_events.csv'
p_file = 'Resources/population_GDP.csv'

# %%
olympics_info = pd.read_csv(file)
olympics_info.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
population_data = pd.read_csv(p_file)
population_data.head()
# Out:
#            Country Code      Population   GDP per Capita
# 0      Afghanistan  AFG   32,526,562.00       594.323081
# 1          Albania  ALB    2,889,167.00      3945.217582
# 2          Algeria  ALG   39,666,519.00      4206.031232
# 3  American Samoa*  ASA       55,538.00              NaN
# 4          Andorra  AND       70,473.00              NaN

# %% [markdown]
# # Transform DataFrame

# %% [markdown]
# #    1) Create "Sport" DataFrame and Clean

# %%
# Create a filtered dataframe "Sport" from specific columns
sports_cols = ["Sport", "Event"]
sport_df= olympics_info[sports_cols].copy()

# Rename the column headers
# sport_df = sport_df.rename(columns={"Sport": "sport", "Event": "event"})



sport_df.head()
# Out:
#            Sport                             Event
# 0     Basketball       Basketball Men's Basketball
# 1           Judo      Judo Men's Extra-Lightweight
# 2       Football           Football Men's Football
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4  Speed Skating  Speed Skating Women's 500 metres

# %%
# Stats 
sport_df.count()
# Out:
# Sport    271116
# Event    271116
# dtype: int64

# %%
# Find duplicates, if any
duplicateSportDF = sport_df[sport_df.duplicated("Sport")]

print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateSportDF)
print(duplicateSportDF.count())
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#                 Sport                                     Event
# 5       Speed Skating        Speed Skating Women's 1,000 metres
# 6       Speed Skating          Speed Skating Women's 500 metres
# 7       Speed Skating        Speed Skating Women's 1,000 metres
# 8       Speed Skating          Speed Skating Women's 500 metres
# 9       Speed Skating        Speed Skating Women's 1,000 metres
# ...               ...                                       ...
# 271111           Luge                Luge Mixed (Men)'s Doubles
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team
# 271114      Bobsleigh                      Bobsleigh Men's Four
# 271115      Bobsleigh                      Bobsleigh Men's Four
#
# [271050 rows x 2 columns]
# Sport    271050
# Event    271050
# dtype: int64

# %%
# Clean the data by dropping duplicates 
sport_table = sport_df.drop_duplicates("Sport")
sport_table.head()
# Out:
#            Sport                             Event
# 0     Basketball       Basketball Men's Basketball
# 1           Judo      Judo Men's Extra-Lightweight
# 2       Football           Football Men's Football
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4  Speed Skating  Speed Skating Women's 500 metres

# %%
sport_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 0 to 214105
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sport   66 non-null     object
#  1   Event   66 non-null     object
# dtypes: object(2)
# memory usage: 1.5+ KB

# %%
# Sort Event ascending order
sport_table = sport_table.sort_values('Event')
sport_table
# Out:
#                    Sport                                              Event
# 214105       Aeronautics                      Aeronautics Mixed Aeronautics
# 59         Alpine Skiing                       Alpine Skiing Men's Downhill
# 30323           Alpinism                            Alpinism Mixed Alpinism
# 287              Archery                         Archery Women's Individual
# 58      Art Competitions  Art Competitions Mixed Sculpturing, Unknown Event
# ...                  ...                                                ...
# 3             Tug-Of-War                        Tug-Of-War Men's Tug-Of-War
# 291           Volleyball                        Volleyball Men's Volleyball
# 88            Water Polo                        Water Polo Men's Water Polo
# 80         Weightlifting            Weightlifting Women's Super-Heavyweight
# 81             Wrestling     Wrestling Men's Light-Heavyweight, Greco-Roman
#
# [66 rows x 2 columns]

# %%
sport_table.insert(0, 'id', range(1, 1 + len(sport_table)))

sport_table.head()
# Out:
#         id             Sport  \
# 214105   1       Aeronautics
# 59       2     Alpine Skiing
# 30323    3          Alpinism
# 287      4           Archery
# 58       5  Art Competitions
#
#                                                     Event
# 214105                      Aeronautics Mixed Aeronautics
# 59                           Alpine Skiing Men's Downhill
# 30323                             Alpinism Mixed Alpinism
# 287                            Archery Women's Individual
# 58      Art Competitions Mixed Sculpturing, Unknown Event

# %%
# Clean df stats
print(sport_table.count())
# Out:
# id       66
# Sport    66
# Event    66
# dtype: int64

# %%
# Create a new filtered dataframe "Sport" from specific columns
sports_cols = ["Sport"]
sport_final = olympics_info[sports_cols].copy()

# Rename the column headers
sport_final = sport_final.rename(columns={"Sport": "sport"})

# Delete duplicates
sport_final = sport_final.drop_duplicates("sport")

sport_final.head()
# Out:
#            sport
# 0     Basketball
# 1           Judo
# 2       Football
# 3     Tug-Of-War
# 4  Speed Skating

# %%
# Sort Event ascending order
sport_final = sport_final.sort_values('sport')
sport_final
# Out:
#                    sport
# 214105       Aeronautics
# 59         Alpine Skiing
# 30323           Alpinism
# 287              Archery
# 58      Art Competitions
# ...                  ...
# 3             Tug-Of-War
# 291           Volleyball
# 88            Water Polo
# 80         Weightlifting
# 81             Wrestling
#
# [66 rows x 1 columns]

# %%
sport_final.insert(0, 'id', range(1, 1 + len(sport_final)))

sport_final.head()
# Out:
#         id             sport
# 214105   1       Aeronautics
# 59       2     Alpine Skiing
# 30323    3          Alpinism
# 287      4           Archery
# 58       5  Art Competitions

# %%
sport_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 214105 to 81
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      66 non-null     int32
#  1   sport   66 non-null     object
# dtypes: int32(1), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# #   2) Create "Event" DataFrame and Clean

# %%
# Create a filtered dataframe "Events" from specific columns
event_df = pd.DataFrame(olympics_info, columns= ["Event", "Name", "City", "Year", "Season"].copy())

event_df.head()
# Out:
#                               Event                      Name       City  \
# 0       Basketball Men's Basketball                 A Dijiang  Barcelona
# 1      Judo Men's Extra-Lightweight                  A Lamusi     London
# 2           Football Men's Football       Gunnar Nielsen Aaby  Antwerpen
# 3       Tug-Of-War Men's Tug-Of-War      Edgar Lindenau Aabye      Paris
# 4  Speed Skating Women's 500 metres  Christine Jacoba Aaftink    Calgary
#
#    Year  Season
# 0  1992  Summer
# 1  2012  Summer
# 2  1920  Summer
# 3  1900  Summer
# 4  1988  Winter

# %%
# Stats
print(event_df.count())
# Out:
# Event     271116
# Name      271116
# City      271116
# Year      271116
# Season    271116
# dtype: int64

# %%
# Find duplicates, if any based on the Event column
duplicateEventDF = event_df[event_df.duplicated(['Event'])]
sort_by_event = duplicateEventDF.sort_values('Event')

print("Duplicate Rows except first occurrence based the Event column are :")
print(sort_by_event.head())
print(sort_by_event.count())
# Out:
# Duplicate Rows except first occurrence based the Event column are :
#                                Event                          Name  \
# 85467   Alpine Skiing Men's Combined               Jrg Grnenfelder
# 70241   Alpine Skiing Men's Combined                Chad Fleischer
# 58962   Alpine Skiing Men's Combined  Philippe Marie Eugne d'Ursel
# 154995  Alpine Skiing Men's Combined  Robert Lloyd "Barney" McLean
# 70243   Alpine Skiing Men's Combined                Chad Fleischer
#
#                 City  Year  Season
# 85467         Nagano  1998  Winter
# 70241    Lillehammer  1994  Winter
# 58962   Sankt Moritz  1948  Winter
# 154995  Sankt Moritz  1948  Winter
# 70243         Nagano  1998  Winter
# Event     270351
# Name      270351
# City      270351
# Year      270351
# Season    270351
# dtype: int64

# %%
# Clean the data by dropping duplicates and setting the index
event_df.drop_duplicates("Event", inplace=True)

event_df.head()
# Out:
#                               Event                      Name       City  \
# 0       Basketball Men's Basketball                 A Dijiang  Barcelona
# 1      Judo Men's Extra-Lightweight                  A Lamusi     London
# 2           Football Men's Football       Gunnar Nielsen Aaby  Antwerpen
# 3       Tug-Of-War Men's Tug-Of-War      Edgar Lindenau Aabye      Paris
# 4  Speed Skating Women's 500 metres  Christine Jacoba Aaftink    Calgary
#
#    Year  Season
# 0  1992  Summer
# 1  2012  Summer
# 2  1920  Summer
# 3  1900  Summer
# 4  1988  Winter

# %%
event_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 765 entries, 0 to 214105
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Event   765 non-null    object
#  1   Name    765 non-null    object
#  2   City    765 non-null    object
#  3   Year    765 non-null    int64
#  4   Season  765 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 35.9+ KB

# %%
# Sort Event ascending order
event_df = event_df.sort_values('Event')
event_df
# Out:
#                                                  Event  \
# 214105                   Aeronautics Mixed Aeronautics
# 67                        Alpine Skiing Men's Combined
# 59                        Alpine Skiing Men's Downhill
# 61                    Alpine Skiing Men's Giant Slalom
# 62                          Alpine Skiing Men's Slalom
# ...                                                ...
# 10885           Wrestling Women's Flyweight, Freestyle
# 1552          Wrestling Women's Heavyweight, Freestyle
# 1285    Wrestling Women's Light-Heavyweight, Freestyle
# 1667          Wrestling Women's Lightweight, Freestyle
# 12341        Wrestling Women's Middleweight, Freestyle
#
#                                  Name            City  Year  Season
# 214105              Hermann Schreiber          Berlin  1936  Summer
# 67                 Kjetil Andr Aamodt     Lillehammer  1994  Winter
# 59                 Kjetil Andr Aamodt     Albertville  1992  Winter
# 61                 Kjetil Andr Aamodt     Albertville  1992  Winter
# 62                 Kjetil Andr Aamodt     Albertville  1992  Winter
# ...                               ...             ...   ...     ...
# 10885              Haley Ruth Augello  Rio de Janeiro  2016  Summer
# 1552                     Yasemin Adar  Rio de Janeiro  2016  Summer
# 1285           Mara Jos Acosta Acosta  Rio de Janeiro  2016  Summer
# 1667    Aminat Oluwafunmilayo Adeniyi  Rio de Janeiro  2016  Summer
# 12341            Badrakhyn Odonchimeg         Beijing  2008  Summer
#
# [765 rows x 5 columns]

# %%
event_df.insert(0, 'id', range(1, 1 + len(event_df)))
# event_df.set_index("id", inplace=True)

event_df.head()
# Out:
#         id                             Event                Name         City  \
# 214105   1     Aeronautics Mixed Aeronautics   Hermann Schreiber       Berlin
# 67       2      Alpine Skiing Men's Combined  Kjetil Andr Aamodt  Lillehammer
# 59       3      Alpine Skiing Men's Downhill  Kjetil Andr Aamodt  Albertville
# 61       4  Alpine Skiing Men's Giant Slalom  Kjetil Andr Aamodt  Albertville
# 62       5        Alpine Skiing Men's Slalom  Kjetil Andr Aamodt  Albertville
#
#         Year  Season
# 214105  1936  Summer
# 67      1994  Winter
# 59      1992  Winter
# 61      1992  Winter
# 62      1992  Winter

# %% [markdown]
# # Create dataframe  for table Olympic Season

# %%
#Create dataframe from specific columns for table Olympic Season
oly_season_columns = ["Year", "City", "Season"]
new_oly_season_data_df = olympics_info[oly_season_columns].copy()

                                                      

#Clean the data by dropping duplicates and setting index
new_oly_season_data_df.drop_duplicates("Year", inplace=True)
# new_oly_season_data_df["id"]= new_oly_season_data_df.index+1
#new_oly_season_data_df.set_index("id", inplace=True)
new_oly_season_data_df.head()
# Out:
#    Year       City  Season
# 0  1992  Barcelona  Summer
# 1  2012     London  Summer
# 2  1920  Antwerpen  Summer
# 3  1900      Paris  Summer
# 4  1988    Calgary  Winter

# %%
new_oly_season_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 3079
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    35 non-null     int64
#  1   City    35 non-null     object
#  2   Season  35 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.1+ KB

# %%
new_oly_season_data_df.insert(0, 'id', range(1, 1 + len(new_oly_season_data_df)))

new_oly_season_data_df.head()
# Out:
#    id  Year       City  Season
# 0   1  1992  Barcelona  Summer
# 1   2  2012     London  Summer
# 2   3  1920  Antwerpen  Summer
# 3   4  1900      Paris  Summer
# 4   5  1988    Calgary  Winter

# %% [markdown]
# # Create dataframe for table Athlete

# %%
# Create dataframe from specific columns for table Athlete
athlete_columns = ["Name", "Sex", "NOC"]
new_athlete_data_df = olympics_info[athlete_columns].copy()



#Rename the columns headers
# new_athlete_data_df = new_athlete_data_df.rename(columns={"Name": "name",
#                                                           "Sex": "sex",
#                                                           "NOC":"country_code"})

new_athlete_data_df.drop_duplicates("Name", inplace=True)
    
# new_athlete_data_df.insert(0, 'id', range(1, 1 + len(new_athlete_data_df)))



new_athlete_data_df.head()
# Out:
#                        Name Sex  NOC
# 0                 A Dijiang   M  CHN
# 1                  A Lamusi   M  CHN
# 2       Gunnar Nielsen Aaby   M  DEN
# 3      Edgar Lindenau Aabye   M  DEN
# 4  Christine Jacoba Aaftink   F  NED

# %%
new_athlete_data_df.insert(0, 'id', range(1, 1 + len(new_athlete_data_df)))
# new_athlete_data_df.drop_duplicates(subset='name')

new_athlete_data_df
# Out:
#             id                          Name Sex  NOC
# 0            1                     A Dijiang   M  CHN
# 1            2                      A Lamusi   M  CHN
# 2            3           Gunnar Nielsen Aaby   M  DEN
# 3            4          Edgar Lindenau Aabye   M  DEN
# 4            5      Christine Jacoba Aaftink   F  NED
# ...        ...                           ...  ..  ...
# 271108  134728  Aleksandr Viktorovich Zyuzin   M  RUS
# 271110  134729        Olga Igorevna Zyuzkova   F  BLR
# 271111  134730                    Andrzej ya   M  POL
# 271112  134731                      Piotr ya   M  POL
# 271114  134732            Tomasz Ireneusz ya   M  POL
#
# [134732 rows x 4 columns]

# %% [markdown]
# # Create country df

# %%
#create country df

country_pd = population_data[['Code','Country']]

country_rename = country_pd.rename(columns={'Code':'country_code', 'Country':'country'})

country_rename['id'] = ""

country_rename['id'] = country_rename['id'].index + 1

country = country_rename[['id','country_code','country']]

country.head()

# %% [markdown]
# #  Joins

# %%
event_athlete_df = pd.merge(event_df, new_athlete_data_df, how='inner', on='Name')
event_athlete_df
# Out:
#      id_x                                           Event  \
# 0       1                   Aeronautics Mixed Aeronautics
# 1       2                    Alpine Skiing Men's Combined
# 2       3                    Alpine Skiing Men's Downhill
# 3       4                Alpine Skiing Men's Giant Slalom
# 4       5                      Alpine Skiing Men's Slalom
# ..    ...                                             ...
# 760   761          Wrestling Women's Flyweight, Freestyle
# 761   762        Wrestling Women's Heavyweight, Freestyle
# 762   763  Wrestling Women's Light-Heavyweight, Freestyle
# 763   764        Wrestling Women's Lightweight, Freestyle
# 764   765       Wrestling Women's Middleweight, Freestyle
#
#                               Name            City  Year  Season    id_y Sex  \
# 0                Hermann Schreiber          Berlin  1936  Summer  106890   M
# 1               Kjetil Andr Aamodt     Lillehammer  1994  Winter      20   M
# 2               Kjetil Andr Aamodt     Albertville  1992  Winter      20   M
# 3               Kjetil Andr Aamodt     Albertville  1992  Winter      20   M
# 4               Kjetil Andr Aamodt     Albertville  1992  Winter      20   M
# ..                             ...             ...   ...     ...     ...  ..
# 760             Haley Ruth Augello  Rio de Janeiro  2016  Summer    5926   F
# 761                   Yasemin Adar  Rio de Janeiro  2016  Summer     861   F
# 762         Mara Jos Acosta Acosta  Rio de Janeiro  2016  Summer     719   F
# 763  Aminat Oluwafunmilayo Adeniyi  Rio de Janeiro  2016  Summer     921   F
# 764           Badrakhyn Odonchimeg         Beijing  2008  Summer    6682   F
#
#      NOC
# 0    SUI
# 1    NOR
# 2    NOR
# 3    NOR
# 4    NOR
# ..   ...
# 760  USA
# 761  TUR
# 762  VEN
# 763  NGR
# 764  MGL
#
# [765 rows x 9 columns]

# %%
#Rename the columns headers
event_athlete_df = event_athlete_df.rename(columns={"id_x": "id", "id_y": "athlete_id"})
event_athlete_df
# Out:
#       id                                           Event  \
# 0      1                   Aeronautics Mixed Aeronautics
# 1      2                    Alpine Skiing Men's Combined
# 2      3                    Alpine Skiing Men's Downhill
# 3      4                Alpine Skiing Men's Giant Slalom
# 4      5                      Alpine Skiing Men's Slalom
# ..   ...                                             ...
# 760  761          Wrestling Women's Flyweight, Freestyle
# 761  762        Wrestling Women's Heavyweight, Freestyle
# 762  763  Wrestling Women's Light-Heavyweight, Freestyle
# 763  764        Wrestling Women's Lightweight, Freestyle
# 764  765       Wrestling Women's Middleweight, Freestyle
#
#                               Name            City  Year  Season  athlete_id  \
# 0                Hermann Schreiber          Berlin  1936  Summer      106890
# 1               Kjetil Andr Aamodt     Lillehammer  1994  Winter          20
# 2               Kjetil Andr Aamodt     Albertville  1992  Winter          20
# 3               Kjetil Andr Aamodt     Albertville  1992  Winter          20
# 4               Kjetil Andr Aamodt     Albertville  1992  Winter          20
# ..                             ...             ...   ...     ...         ...
# 760             Haley Ruth Augello  Rio de Janeiro  2016  Summer        5926
# 761                   Yasemin Adar  Rio de Janeiro  2016  Summer         861
# 762         Mara Jos Acosta Acosta  Rio de Janeiro  2016  Summer         719
# 763  Aminat Oluwafunmilayo Adeniyi  Rio de Janeiro  2016  Summer         921
# 764           Badrakhyn Odonchimeg         Beijing  2008  Summer        6682
#
#     Sex  NOC
# 0     M  SUI
# 1     M  NOR
# 2     M  NOR
# 3     M  NOR
# 4     M  NOR
# ..   ..  ...
# 760   F  USA
# 761   F  TUR
# 762   F  VEN
# 763   F  NGR
# 764   F  MGL
#
# [765 rows x 9 columns]

# %%
event_sport_df = pd.merge(event_athlete_df, sport_table, how='inner', on='Event')
event_sport_df
# Out:
#     id_x                                              Event  \
# 0      1                      Aeronautics Mixed Aeronautics
# 1      3                       Alpine Skiing Men's Downhill
# 2     12                            Alpinism Mixed Alpinism
# 3     39                         Archery Women's Individual
# 4     69  Art Competitions Mixed Sculpturing, Unknown Event
# ..   ...                                                ...
# 61   710                        Tug-Of-War Men's Tug-Of-War
# 62   711                        Volleyball Men's Volleyball
# 63   713                        Water Polo Men's Water Polo
# 64   735            Weightlifting Women's Super-Heavyweight
# 65   748     Wrestling Men's Light-Heavyweight, Greco-Roman
#
#                        Name            City  Year  Season  athlete_id Sex  \
# 0         Hermann Schreiber          Berlin  1936  Summer      106890   M
# 1        Kjetil Andr Aamodt     Albertville  1992  Winter          20   M
# 2   Charles Granville Bruce        Chamonix  1924  Winter       15615   M
# 3           Khadija Abbouda         Beijing  2008  Summer         153   F
# 4     Win Valdemar Aaltonen          London  1948  Summer          19   M
# ..                      ...             ...   ...     ...         ...  ..
# 61     Edgar Lindenau Aabye           Paris  1900  Summer           4   M
# 62     Mahmoud Abd El-Kader         Beijing  2008  Summer         155   M
# 63            Johan Aantjes     Los Angeles  1984  Summer          27   M
# 64            Andreea Aanei  Rio de Janeiro  2016  Summer          22   F
# 65              Fritz Aanes          Sydney  2000  Summer          23   M
#
#     NOC  id_y             Sport
# 0   SUI     1       Aeronautics
# 1   NOR     2     Alpine Skiing
# 2   GBR     3          Alpinism
# 3   MAR     4           Archery
# 4   FIN     5  Art Competitions
# ..  ...   ...               ...
# 61  DEN    62        Tug-Of-War
# 62  EGY    63        Volleyball
# 63  NED    64        Water Polo
# 64  ROU    65     Weightlifting
# 65  NOR    66         Wrestling
#
# [66 rows x 11 columns]

# %%
event_sport_df = event_sport_df.rename(columns={"id_x": "id", "id_y": "sport_id"})
event_sport_df
# Out:
#      id                                              Event  \
# 0     1                      Aeronautics Mixed Aeronautics
# 1     3                       Alpine Skiing Men's Downhill
# 2    12                            Alpinism Mixed Alpinism
# 3    39                         Archery Women's Individual
# 4    69  Art Competitions Mixed Sculpturing, Unknown Event
# ..  ...                                                ...
# 61  710                        Tug-Of-War Men's Tug-Of-War
# 62  711                        Volleyball Men's Volleyball
# 63  713                        Water Polo Men's Water Polo
# 64  735            Weightlifting Women's Super-Heavyweight
# 65  748     Wrestling Men's Light-Heavyweight, Greco-Roman
#
#                        Name            City  Year  Season  athlete_id Sex  \
# 0         Hermann Schreiber          Berlin  1936  Summer      106890   M
# 1        Kjetil Andr Aamodt     Albertville  1992  Winter          20   M
# 2   Charles Granville Bruce        Chamonix  1924  Winter       15615   M
# 3           Khadija Abbouda         Beijing  2008  Summer         153   F
# 4     Win Valdemar Aaltonen          London  1948  Summer          19   M
# ..                      ...             ...   ...     ...         ...  ..
# 61     Edgar Lindenau Aabye           Paris  1900  Summer           4   M
# 62     Mahmoud Abd El-Kader         Beijing  2008  Summer         155   M
# 63            Johan Aantjes     Los Angeles  1984  Summer          27   M
# 64            Andreea Aanei  Rio de Janeiro  2016  Summer          22   F
# 65              Fritz Aanes          Sydney  2000  Summer          23   M
#
#     NOC  sport_id             Sport
# 0   SUI         1       Aeronautics
# 1   NOR         2     Alpine Skiing
# 2   GBR         3          Alpinism
# 3   MAR         4           Archery
# 4   FIN         5  Art Competitions
# ..  ...       ...               ...
# 61  DEN        62        Tug-Of-War
# 62  EGY        63        Volleyball
# 63  NED        64        Water Polo
# 64  ROU        65     Weightlifting
# 65  NOR        66         Wrestling
#
# [66 rows x 11 columns]

# %%
event_olympics_season_df = pd.merge(event_sport_df, new_oly_season_data_df, how='inner', on='Year')
event_olympics_season_df.head()
# Out:
#    id_x                                              Event  \
# 0     1                      Aeronautics Mixed Aeronautics
# 1   419                 Modern Pentathlon Men's Individual
# 2   561  Shooting Men's Small-Bore Rifle, Prone, 50 metres
# 3     3                       Alpine Skiing Men's Downhill
# 4   160                        Basketball Men's Basketball
#
#                  Name       City_x  Year Season_x  athlete_id Sex  NOC  \
# 0   Hermann Schreiber       Berlin  1936   Summer      106890   M  SUI
# 1        Silvano Abba       Berlin  1936   Summer         103   M  ITA
# 2         Hakon Aasns       Berlin  1936   Summer          45   M  NOR
# 3  Kjetil Andr Aamodt  Albertville  1992   Winter          20   M  NOR
# 4           A Dijiang    Barcelona  1992   Summer           1   M  CHN
#
#    sport_id              Sport  id_y     City_y Season_y
# 0         1        Aeronautics    27     Berlin   Summer
# 1        37  Modern Pentathlon    27     Berlin   Summer
# 2        48           Shooting    27     Berlin   Summer
# 3         2      Alpine Skiing     1  Barcelona   Summer
# 4         9         Basketball     1  Barcelona   Summer

# %%
#Rename the columns headers
event_table_final = event_olympics_season_df.rename(columns={"id_x": "id", "id_y": "olympic_season_id", "Event": "event_name"})
event_table_final.head()
# Out:
#     id                                         event_name                Name  \
# 0    1                      Aeronautics Mixed Aeronautics   Hermann Schreiber
# 1  419                 Modern Pentathlon Men's Individual        Silvano Abba
# 2  561  Shooting Men's Small-Bore Rifle, Prone, 50 metres         Hakon Aasns
# 3    3                       Alpine Skiing Men's Downhill  Kjetil Andr Aamodt
# 4  160                        Basketball Men's Basketball           A Dijiang
#
#         City_x  Year Season_x  athlete_id Sex  NOC  sport_id  \
# 0       Berlin  1936   Summer      106890   M  SUI         1
# 1       Berlin  1936   Summer         103   M  ITA        37
# 2       Berlin  1936   Summer          45   M  NOR        48
# 3  Albertville  1992   Winter          20   M  NOR         2
# 4    Barcelona  1992   Summer           1   M  CHN         9
#
#                Sport  olympic_season_id     City_y Season_y
# 0        Aeronautics                 27     Berlin   Summer
# 1  Modern Pentathlon                 27     Berlin   Summer
# 2           Shooting                 27     Berlin   Summer
# 3      Alpine Skiing                  1  Barcelona   Summer
# 4         Basketball                  1  Barcelona   Summer

# %%
event_table_final.drop(['Name', 'City_x', 'Year', 'Season_x', 'Sex', 'NOC', 'Sport', 'City_y', 'Season_y'], axis=1, inplace=True)
event_table_final
# Out:
#      id                                         event_name  athlete_id  \
# 0     1                      Aeronautics Mixed Aeronautics      106890
# 1   419                 Modern Pentathlon Men's Individual         103
# 2   561  Shooting Men's Small-Bore Rifle, Prone, 50 metres          45
# 3     3                       Alpine Skiing Men's Downhill          20
# 4   160                        Basketball Men's Basketball           1
# ..  ...                                                ...         ...
# 61  463                  Rugby Sevens Women's Rugby Sevens         440
# 62  706                      Trampolining Men's Individual         561
# 63  709                 Triathlon Women's Olympic Distance         577
# 64  735            Weightlifting Women's Super-Heavyweight          22
# 65  651                Swimming Men's 400 metres Freestyle          10
#
#     sport_id  olympic_season_id
# 0          1                 27
# 1         37                 27
# 2         48                 27
# 3          2                  1
# 4          9                  1
# ..       ...                ...
# 61        46                 20
# 62        60                 20
# 63        61                 20
# 64        65                 20
# 65        55                  9
#
# [66 rows x 5 columns]

# %% [markdown]
# # Scratchpad

# %%
joined_df = pd.merge(new_athlete_data_df,country, how='inner', on='country_code')
joined_df

# %%
athlete_df = joined_df.drop(['country_code', 'country'], axis=1)
athlete_df = athlete_df.rename(columns={'id_x':'id', 'id_y':'nationality'})
athlete_df

# %%
event_joined_df = pd.merge(new_athlete_data_df,country, how='inner', on='country_code')
joined_df

# %%
athlete_id = country_pd.rename(columns={'Code':'country_code', 'Country':'country'})

# %% [markdown]
# # Create database connection

# %%
connection_string = f'{username}:{password}@localhost:5432/olympics_db'
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['country',
#  'athlete',
#  'event',
#  'sport',
#  'olympic_season',
#  'athlete_event',
#  'country_stats']

# %% [markdown]
# # Load DataFrames into database

# %%
sport_final.to_sql(name='sport', con=engine, if_exists='append', index=False)

# %%
event_table_final.to_sql(name='event', con=engine, if_exists='append', index=False)

# %% [markdown]
# # Confirm data uploaded correctly

# %%
pd.read_sql_query('select * from sport', con=engine).head()
# Out:
#    id             sport
# 0   1       Aeronautics
# 1   2     Alpine Skiing
# 2   3          Alpinism
# 3   4           Archery
# 4   5  Art Competitions
