# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Extract CSV into DataFrame

# %%
file = 'athlete_events.csv'

# %%
olympics_info = pd.read_csv(file)
olympics_info.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# # Transform DataFrame

# %% [markdown]
# #    1) Create "Sport" DataFrame and Clean

# %%
# Create a filtered dataframe "Sport" from specific columns
sports_cols = ["Sport"]
sport_df= olympics_info[sports_cols].copy()

# Rename the column headers
# premise_transformed = premise_transformed.rename(columns={"License Serial Number": "id",
#                                                           "Premises Name": "premise_name",
#                                                           "County ID Code": "county_id"})



sport_df.head()
# Out:
#            Sport
# 0     Basketball
# 1           Judo
# 2       Football
# 3     Tug-Of-War
# 4  Speed Skating

# %%
# Stats 
sport_df.count()
# Out:
# Sport    271116
# dtype: int64

# %%
# Find duplicates, if any
duplicateSportDF = sport_df[sport_df.duplicated()]

print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateSportDF)
print(duplicateSportDF.count())
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#                 Sport
# 5       Speed Skating
# 6       Speed Skating
# 7       Speed Skating
# 8       Speed Skating
# 9       Speed Skating
# ...               ...
# 271111           Luge
# 271112    Ski Jumping
# 271113    Ski Jumping
# 271114      Bobsleigh
# 271115      Bobsleigh
#
# [271050 rows x 1 columns]
# Sport    271050
# dtype: int64

# %%
# Clean the data by dropping duplicates 
sport_table = sport_df.drop_duplicates("Sport")

sport_table.head()
# Out:
#            Sport
# 0     Basketball
# 1           Judo
# 2       Football
# 3     Tug-Of-War
# 4  Speed Skating

# %%
# Clean df stats
print(sport_table.count())
# Out:
# Sport    66
# dtype: int64

# %% [markdown]
# #   2) Create "Event" DataFrame and Clean

# %%
# Create a filtered dataframe "Events" from specific columns
events_cols = ["Sport", "Event"]
event_df = pd.DataFrame(olympics_info, columns= ["Sport", "Event"].copy())

# Rename the column headers
# premise_transformed = premise_transformed.rename(columns={"License Serial Number": "id",
#                                                           "Premises Name": "premise_name",
#                                                           "County ID Code": "county_id"})


event_df.head()
# Out:
#            Sport                             Event
# 0     Basketball       Basketball Men's Basketball
# 1           Judo      Judo Men's Extra-Lightweight
# 2       Football           Football Men's Football
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4  Speed Skating  Speed Skating Women's 500 metres

# %%
# Stats
print(event_df.count())
# Out:
# Sport    271116
# Event    271116
# dtype: int64

# %%
# Find duplicates, if any based on the Event column
duplicateEventDF = event_df[event_df.duplicated(['Event'])]
sort_by_event = duplicateEventDF.sort_values('Event')

print("Duplicate Rows except first occurrence based the Event column are :")
print(sort_by_event.head())
print(sort_by_event.count())
# Out:
# Duplicate Rows except first occurrence based the Event column are :
#                 Sport                         Event
# 85467   Alpine Skiing  Alpine Skiing Men's Combined
# 70241   Alpine Skiing  Alpine Skiing Men's Combined
# 58962   Alpine Skiing  Alpine Skiing Men's Combined
# 154995  Alpine Skiing  Alpine Skiing Men's Combined
# 70243   Alpine Skiing  Alpine Skiing Men's Combined
# Sport    270351
# Event    270351
# dtype: int64

# %%
# Clean the data by dropping duplicates and setting the index
event_df.drop_duplicates("Event", inplace=True)
# premise_transformed.set_index("id", inplace=True)

event_df.head()
# Out:
#            Sport                             Event
# 0     Basketball       Basketball Men's Basketball
# 1           Judo      Judo Men's Extra-Lightweight
# 2       Football           Football Men's Football
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4  Speed Skating  Speed Skating Women's 500 metres

# %%
g_by_sport = event_df.groupby("Sport")["Event"].count()
print(g_by_sport)
# Out:
# Sport
# Aeronautics          1
# Alpine Skiing       10
# Alpinism             1
# Archery             29
# Art Competitions    29
#                     ..
# Tug-Of-War           1
# Volleyball           2
# Water Polo           2
# Weightlifting       21
# Wrestling           30
# Name: Event, Length: 66, dtype: int64

# %%
# Clean df stats
print(event_df.count())
# Out:
# Sport    765
# Event    765
# dtype: int64

# %% [markdown]
# # Cleaning start

# %%
event_df[event_df['Sport'].str.contains(r'Ski(?!$)')]
# Out:
#                       Sport  \
# 10     Cross Country Skiing
# 11     Cross Country Skiing
# 12     Cross Country Skiing
# 13     Cross Country Skiing
# 15     Cross Country Skiing
# 59            Alpine Skiing
# 60            Alpine Skiing
# 61            Alpine Skiing
# 62            Alpine Skiing
# 67            Alpine Skiing
# 121    Cross Country Skiing
# 252           Alpine Skiing
# 726        Freestyle Skiing
# 782        Freestyle Skiing
# 808           Alpine Skiing
# 809           Alpine Skiing
# 815    Cross Country Skiing
# 816    Cross Country Skiing
# 817    Cross Country Skiing
# 976    Cross Country Skiing
# 1210   Cross Country Skiing
# 1310          Alpine Skiing
# 1326            Ski Jumping
# 1641       Freestyle Skiing
# 1792          Alpine Skiing
# 1915       Freestyle Skiing
# 1952   Cross Country Skiing
# 2157   Cross Country Skiing
# 2158   Cross Country Skiing
# 2550            Ski Jumping
# 2551            Ski Jumping
# 2697       Freestyle Skiing
# 4135   Cross Country Skiing
# 4136   Cross Country Skiing
# 4137   Cross Country Skiing
# 4145   Cross Country Skiing
# 4889       Freestyle Skiing
# 5430   Cross Country Skiing
# 5485            Ski Jumping
# 5782   Cross Country Skiing
# 6182   Cross Country Skiing
# 7060   Cross Country Skiing
# 7379   Cross Country Skiing
# 10854   Military Ski Patrol
# 12763      Freestyle Skiing
# 14827      Freestyle Skiing
# 14883      Freestyle Skiing
# 20654      Freestyle Skiing
#
#                                                    Event  \
# 10              Cross Country Skiing Men's 10 kilometres
# 11              Cross Country Skiing Men's 50 kilometres
# 12     Cross Country Skiing Men's 10/15 kilometres Pu...
# 13     Cross Country Skiing Men's 4 x 10 kilometres R...
# 15              Cross Country Skiing Men's 30 kilometres
# 59                          Alpine Skiing Men's Downhill
# 60                           Alpine Skiing Men's Super G
# 61                      Alpine Skiing Men's Giant Slalom
# 62                            Alpine Skiing Men's Slalom
# 67                          Alpine Skiing Men's Combined
# 121             Cross Country Skiing Men's 15 kilometres
# 252                         Alpine Skiing Women's Slalom
# 726                        Freestyle Skiing Men's Moguls
# 782                       Freestyle Skiing Men's Aerials
# 808                   Alpine Skiing Women's Giant Slalom
# 809                        Alpine Skiing Women's Super G
# 815            Cross Country Skiing Women's 5 kilometres
# 816           Cross Country Skiing Women's 10 kilometres
# 817           Cross Country Skiing Women's 20 kilometres
# 976                    Cross Country Skiing Men's Sprint
# 1210   Cross Country Skiing Women's 3 x 5 kilometres ...
# 1310                      Alpine Skiing Women's Combined
# 1326           Ski Jumping Men's Normal Hill, Individual
# 1641                   Freestyle Skiing Men's Slopestyle
# 1792                      Alpine Skiing Women's Downhill
# 1915                   Freestyle Skiing Women's Halfpipe
# 1952            Cross Country Skiing Men's 18 kilometres
# 2157          Cross Country Skiing Women's 30 kilometres
# 2158        Cross Country Skiing Women's 15 km Skiathlon
# 2550            Ski Jumping Men's Large Hill, Individual
# 2551                  Ski Jumping Men's Large Hill, Team
# 2697                    Freestyle Skiing Women's Aerials
# 4135   Cross Country Skiing Women's 5/10 kilometres P...
# 4136   Cross Country Skiing Women's 4 x 5 kilometres ...
# 4137          Cross Country Skiing Women's 15 kilometres
# 4145   Cross Country Skiing Women's 5/5 kilometres Pu...
# 4889                     Freestyle Skiing Women's Moguls
# 5430   Cross Country Skiing Men's 10/10 kilometres Pu...
# 5485         Ski Jumping Women's Normal Hill, Individual
# 5782              Cross Country Skiing Men's Team Sprint
# 6182                 Cross Country Skiing Women's Sprint
# 7060            Cross Country Skiing Women's Team Sprint
# 7379          Cross Country Skiing Men's 30 km Skiathlon
# 10854      Military Ski Patrol Men's Military Ski Patrol
# 12763                Freestyle Skiing Women's Slopestyle
# 14827                 Freestyle Skiing Women's Ski Cross
# 14883                   Freestyle Skiing Men's Ski Cross
# 20654                    Freestyle Skiing Men's Halfpipe
#
#                             name_updated  \
# 10                   Men's 10 kilometres
# 11                   Men's 50 kilometres
# 12        Men's 10/15 kilometres Pursuit
# 13         Men's 4 x 10 kilometres Relay
# 15                   Men's 30 kilometres
# 59                        Men's Downhill
# 60                         Men's Super G
# 61                    Men's Giant Slalom
# 62                          Men's Slalom
# 67                        Men's Combined
# 121                  Men's 15 kilometres
# 252                       Women's Slalom
# 726                         Men's Moguls
# 782                        Men's Aerials
# 808                 Women's Giant Slalom
# 809                      Women's Super G
# 815                 Women's 5 kilometres
# 816                Women's 10 kilometres
# 817                Women's 20 kilometres
# 976                         Men's Sprint
# 1210      Women's 3 x 5 kilometres Relay
# 1310                    Women's Combined
# 1326       Men's Normal Hill, Individual
# 1641                    Men's Slopestyle
# 1792                    Women's Downhill
# 1915                    Women's Halfpipe
# 1952                 Men's 18 kilometres
# 2157               Women's 30 kilometres
# 2158             Women's 15 km Skiathlon
# 2550        Men's Large Hill, Individual
# 2551              Men's Large Hill, Team
# 2697                     Women's Aerials
# 4135     Women's 5/10 kilometres Pursuit
# 4136      Women's 4 x 5 kilometres Relay
# 4137               Women's 15 kilometres
# 4145      Women's 5/5 kilometres Pursuit
# 4889                      Women's Moguls
# 5430      Men's 10/10 kilometres Pursuit
# 5485     Women's Normal Hill, Individual
# 5782                   Men's Team Sprint
# 6182                      Women's Sprint
# 7060                 Women's Team Sprint
# 7379               Men's 30 km Skiathlon
# 10854                            Men's
# 12763                 Women's Slopestyle
# 14827                  Women's Ski Cross
# 14883                    Men's Ski Cross
# 20654                     Men's Halfpipe
#
#                                        name_updated_2
# 10                 Country Skiing Men's 10 kilometres
# 11                 Country Skiing Men's 50 kilometres
# 12      Country Skiing Men's 10/15 kilometres Pursuit
# 13       Country Skiing Men's 4 x 10 kilometres Relay
# 15                 Country Skiing Men's 30 kilometres
# 59                              Skiing Men's Downhill
# 60                               Skiing Men's Super G
# 61                          Skiing Men's Giant Slalom
# 62                                Skiing Men's Slalom
# 67                              Skiing Men's Combined
# 121                Country Skiing Men's 15 kilometres
# 252                             Skiing Women's Slalom
# 726                               Skiing Men's Moguls
# 782                              Skiing Men's Aerials
# 808                       Skiing Women's Giant Slalom
# 809                            Skiing Women's Super G
# 815               Country Skiing Women's 5 kilometres
# 816              Country Skiing Women's 10 kilometres
# 817              Country Skiing Women's 20 kilometres
# 976                       Country Skiing Men's Sprint
# 1210    Country Skiing Women's 3 x 5 kilometres Relay
# 1310                          Skiing Women's Combined
# 1326            Jumping Men's Normal Hill, Individual
# 1641                          Skiing Men's Slopestyle
# 1792                          Skiing Women's Downhill
# 1915                          Skiing Women's Halfpipe
# 1952               Country Skiing Men's 18 kilometres
# 2157             Country Skiing Women's 30 kilometres
# 2158           Country Skiing Women's 15 km Skiathlon
# 2550             Jumping Men's Large Hill, Individual
# 2551                   Jumping Men's Large Hill, Team
# 2697                           Skiing Women's Aerials
# 4135   Country Skiing Women's 5/10 kilometres Pursuit
# 4136    Country Skiing Women's 4 x 5 kilometres Relay
# 4137             Country Skiing Women's 15 kilometres
# 4145    Country Skiing Women's 5/5 kilometres Pursuit
# 4889                            Skiing Women's Moguls
# 5430    Country Skiing Men's 10/10 kilometres Pursuit
# 5485          Jumping Women's Normal Hill, Individual
# 5782                 Country Skiing Men's Team Sprint
# 6182                    Country Skiing Women's Sprint
# 7060               Country Skiing Women's Team Sprint
# 7379             Country Skiing Men's 30 km Skiathlon
# 10854            Ski Patrol Men's Military Ski Patrol
# 12763                       Skiing Women's Slopestyle
# 14827                        Skiing Women's Ski Cross
# 14883                          Skiing Men's Ski Cross
# 20654                           Skiing Men's Halfpipe

# %%
event_df['name_updated'] = event_df.apply(lambda row : row['Event'].replace(str(row['Sport']), ' '), axis=1)
event_df
# Out:
#                 Sport                                              Event  \
# 0          Basketball                        Basketball Men's Basketball
# 1                Judo                       Judo Men's Extra-Lightweight
# 2            Football                            Football Men's Football
# 3          Tug-Of-War                        Tug-Of-War Men's Tug-Of-War
# 4       Speed Skating                   Speed Skating Women's 500 metres
# ...               ...                                                ...
# 128473  Weightlifting    Weightlifting Men's All-Around Dumbbell Contest
# 186911        Archery               Archery Men's Au Chapelet, 33 metres
# 186912        Archery            Archery Men's Au Cordon Dore, 33 metres
# 194996        Archery  Archery Men's Target Archery, 28 metres, Indiv...
# 214105    Aeronautics                      Aeronautics Mixed Aeronautics
#
#                                    name_updated
# 0                                       Men's
# 1                       Men's Extra-Lightweight
# 2                                       Men's
# 3                                       Men's
# 4                            Women's 500 metres
# ...                                         ...
# 128473        Men's All-Around Dumbbell Contest
# 186911             Men's Au Chapelet, 33 metres
# 186912          Men's Au Cordon Dore, 33 metres
# 194996    Men's Target  , 28 metres, Individual
# 214105                                  Mixed
#
# [765 rows x 3 columns]

# %%
# #1 Split string in "event column" (sport from event description) and keep only event description
name_updated1 = event_df['name_updated'] = event_df.apply(lambda row : row['Event'].replace(str(row['Sport']), ' '), axis=1)
name_updated_df = pd.DataFrame(name_updated1)
name_updated_df.head()
# Out:
#                            0
# 0                    Men's
# 1    Men's Extra-Lightweight
# 2                    Men's
# 3                    Men's
# 4         Women's 500 metres

# %%
# #2 Split string in "event column" (sport from event description) and keep only event description
name_updated2 = event_df["Event"].str.split(" ", n = 1, expand = True) 
name_updated2_df = pd.DataFrame(name_updated2)
name_updated2_df
# Out:
#                     0                                            1
# 0          Basketball                             Men's Basketball
# 1                Judo                      Men's Extra-Lightweight
# 2            Football                               Men's Football
# 3          Tug-Of-War                             Men's Tug-Of-War
# 4               Speed                   Skating Women's 500 metres
# ...               ...                                          ...
# 128473  Weightlifting            Men's All-Around Dumbbell Contest
# 186911        Archery                 Men's Au Chapelet, 33 metres
# 186912        Archery              Men's Au Cordon Dore, 33 metres
# 194996        Archery  Men's Target Archery, 28 metres, Individual
# 214105    Aeronautics                            Mixed Aeronautics
#
# [765 rows x 2 columns]

# %%
event_df['name_updated_2'] = name_updated2_df[1]
event_df.sort_values('name_updated_2')
# Out:
#                  Sport                                              Event  \
# 634    Nordic Combined                   Nordic Combined Men's Individual
# 16145  Nordic Combined  Nordic Combined Men's Large Hill / 10 km, Indi...
# 16144  Nordic Combined  Nordic Combined Men's Normal Hill / 10 km, Ind...
# 1246   Nordic Combined                       Nordic Combined Men's Sprint
# 633    Nordic Combined                         Nordic Combined Men's Team
# ...                ...                                                ...
# 447         Volleyball                      Volleyball Women's Volleyball
# 3546         Taekwondo                     Taekwondo Women's Welterweight
# 32             Sailing                         Sailing Women's Windsurfer
# 549            Fencing                   Fencing Women's epee, Individual
# 6556           Fencing                         Fencing Women's epee, Team
#
#                                   name_updated  \
# 634                           Men's Individual
# 16145     Men's Large Hill / 10 km, Individual
# 16144    Men's Normal Hill / 10 km, Individual
# 1246                              Men's Sprint
# 633                                 Men's Team
# ...                                        ...
# 447                                  Women's
# 3546                      Women's Welterweight
# 32                          Women's Windsurfer
# 549                   Women's epee, Individual
# 6556                        Women's epee, Team
#
#                                        name_updated_2
# 634                         Combined Men's Individual
# 16145   Combined Men's Large Hill / 10 km, Individual
# 16144  Combined Men's Normal Hill / 10 km, Individual
# 1246                            Combined Men's Sprint
# 633                               Combined Men's Team
# ...                                               ...
# 447                                Women's Volleyball
# 3546                             Women's Welterweight
# 32                                 Women's Windsurfer
# 549                          Women's epee, Individual
# 6556                               Women's epee, Team
#
# [765 rows x 4 columns]

# %%
event_df.drop(columns=[])

# %% [markdown]
# # Create database connection

# %%
connection_string = f'{username}:{password}@localhost:5432/customer_db'
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()

# %% [markdown]
# # Load DataFrames into database

# %%
county_transformed.to_sql(name='county', con=engine, if_exists='append', index=True)

# %%
premise_transformed.to_sql(name='premise', con=engine, if_exists='append', index=True)
